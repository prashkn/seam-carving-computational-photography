# %% [markdown]
# ## Seam Carving Implementation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import scipy
import scipy.sparse.linalg
import ipywidgets

# %% [markdown]
# 1. Upload your own photo

# %%
pic_upload = FileUpload(accept="image/*")
pic_upload
# Out:
# FileUpload(value={}, accept='image/*', description='Upload')

# %%
pic_upload.value
# Out:
# {'classic-wooden-chair-illustration-on-white-background-vector.jpg': {'metadata': {'name': 'classic-wooden-chair-illustration-on-white-background-vector.jpg',
#    'type': 'image/jpeg',
#    'size': 145700,
#    'lastModified': 1698939721962},
# ...
